# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import os
import shutil



i = 1
k = 2
with open("/content/gdrive/MyDrive/uni/course_work3/2part.txt", "r") as f:
    source = ''
    emotion = ''
    for line in f:
      k = k + 1
      print(source)
      if k == 3:
        splitedline = line.split('\n')
        source = splitedline[0]
        k = 0
      if k == 1:
        splitedline = line.split(' ')
        emotion = splitedline[0]
      print(emotion)
      if emotion == 'Happiness':
        # print('happy')
        destination = "/content/gdrive/MyDrive/uni/course_work3/расфасовка/happy"
        # if not os.path.samefile(source_file_path, destination_file_path):
        #   print('here')
        dest = shutil.copy2(source, destination)
      if emotion == 'Neutral':
        destination = "/content/gdrive/MyDrive/uni/course_work3/расфасовка/neutral"

        dest = shutil.copy2(source, destination)
      if emotion == 'Fear':
        destination = "/content/gdrive/MyDrive/uni/course_work3/расфасовка/fear"

        dest = shutil.copy2(source, destination)
      if emotion == 'Disgust':
        destination = "/content/gdrive/MyDrive/uni/course_work3/расфасовка/disgust"
        # if not os.path.samefile(source_file_path, destination_file_path):
        dest = shutil.copy2(source, destination)
      if emotion == 'Anger':
        destination = "/content/gdrive/MyDrive/uni/course_work3/расфасовка/angry"
        # if not os.path.samefile(source_file_path, destination_file_path):
        dest = shutil.copy2(source, destination)
      if emotion == 'Sadness':
        destination = "/content/gdrive/MyDrive/uni/course_work3/расфасовка/sad"
        # if not os.path.samefile(source_file_path, destination_file_path):
        dest = shutil.copy2(source, destination)
      if emotion == 'Contempt':
        destination = "/content/gdrive/MyDrive/uni/course_work3/расфасовка/contempt"
        # if not os.path.samefile(source_file_path, destination_file_path):
        dest = shutil.copy2(source, destination)
      if emotion == 'Surprise':
        destination = "/content/gdrive/MyDrive/uni/course_work3/расфасовка/surprise"
        # if not os.path.samefile(source_file_path, destination_file_path):
        dest = shutil.copy2(source, destination)








# # Source path
# source = "/content/gdrive/MyDrive/uni/course_work3/0_1_2.csv"

# # Destination path
# destination = "/content/gdrive/MyDrive/uni/course_work3/translated_cv2"

# dest = shutil.copy2(source, destination)
# Out:
# /content/gdrive/MyDrive/uni/course_work3/gen2/000032 - 2023-05-01T223650.312.jpg
# Happiness
# /content/gdrive/MyDrive/uni/course_work3/gen2/000032 - 2023-05-01T223650.312.jpg
# Happiness
# /content/gdrive/MyDrive/uni/course_work3/gen2/000032 - 2023-05-01T223650.312.jpg
# Happiness
# /content/gdrive/MyDrive/uni/course_work3/gen2/000032 - 2023-05-01T223748.883.jpg
# Neutral
# /content/gdrive/MyDrive/uni/course_work3/gen2/000032 - 2023-05-01T223748.883.jpg
# Neutral
# /content/gdrive/MyDrive/uni/course_work3/gen2/000032 - 2023-05-01T223748.883.jpg
# Neutral
# /content/gdrive/MyDrive/uni/course_work3/gen2/000032 - 2023-05-01T223812.659.jpg
# Fear
# /content/gdrive/MyDrive/uni/course_work3/gen2/000032 - 2023-05-01T223812.659.jpg
# Fear
# /content/gdrive/MyDrive/uni/course_work3/gen2/000032 - 2023-05-01T223812.659.jpg
# Fear
# /content/gdrive/MyDrive/uni/course_work3/gen2/000032 - 2023-05-01T222541.481.jpg
# Happiness
# ...
